# %%
import os
from TTS.utils.config import load_config

# Define paths
project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
config_path = os.path.join(project_dir, 'config', 'custom_config.json')
dataset_path = os.path.join(project_dir, 'moz_dataset')
output_path = os.path.join(project_dir, 'output')
samples_path = os.path.join(project_dir, 'samples')

# Create output directories if they don't exist
os.makedirs(output_path, exist_ok=True)
os.makedirs(samples_path, exist_ok=True)

# Load configuration
config = load_config(config_path)
print("Configuration loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 from TTS.utils.config import load_config
#       4 # Define paths
#       5 project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
#
# ModuleNotFoundError: No module named 'TTS.utils.config'

# %%
# Preprocess the dataset
# !tts --config_path {config_path} --action preprocess
# Train the TTS model
# !tts --config_path {config_path} --action train
# Out:
# usage: tts [-h] [--list_models [LIST_MODELS]]
#            [--model_info_by_idx MODEL_INFO_BY_IDX]
#            [--model_info_by_name MODEL_INFO_BY_NAME] [--text TEXT]
#            [--model_name MODEL_NAME] [--vocoder_name VOCODER_NAME]
#            [--config_path CONFIG_PATH] [--model_path MODEL_PATH]
#            [--out_path OUT_PATH] [--use_cuda USE_CUDA] [--device DEVICE]
#            [--vocoder_path VOCODER_PATH]
#            [--vocoder_config_path VOCODER_CONFIG_PATH]
#            [--encoder_path ENCODER_PATH]
#            [--encoder_config_path ENCODER_CONFIG_PATH] [--pipe_out [PIPE_OUT]]
#            [--speakers_file_path SPEAKERS_FILE_PATH]
#            [--language_ids_file_path LANGUAGE_IDS_FILE_PATH]
#            [--speaker_idx SPEAKER_IDX] [--language_idx LANGUAGE_IDX]
#            [--speaker_wav SPEAKER_WAV [SPEAKER_WAV ...]]
#            [--gst_style GST_STYLE]
#            [--capacitron_style_wav CAPACITRON_STYLE_WAV]
#            [--capacitron_style_text CAPACITRON_STYLE_TEXT]
#            [--list_speaker_idxs [LIST_SPEAKER_IDXS]]
#            [--list_language_idxs [LIST_LANGUAGE_IDXS]]
#            [--save_spectogram SAVE_SPECTOGRAM] [--reference_wav REFERENCE_WAV]
#            [--reference_speaker_idx REFERENCE_SPEAKER_IDX]
#            [--progress_bar PROGRESS_BAR] [--source_wav SOURCE_WAV]
#            [--target_wav TARGET_WAV] [--voice_dir VOICE_DIR]
# tts: error: unrecognized arguments: --action preprocess
# usage: tts [-h] [--list_models [LIST_MODELS]]
#            [--model_info_by_idx MODEL_INFO_BY_IDX]
#            [--model_info_by_name MODEL_INFO_BY_NAME] [--text TEXT]
#            [--model_name MODEL_NAME] [--vocoder_name VOCODER_NAME]
#            [--config_path CONFIG_PATH] [--model_path MODEL_PATH]
#            [--out_path OUT_PATH] [--use_cuda USE_CUDA] [--device DEVICE]
#            [--vocoder_path VOCODER_PATH]
#            [--vocoder_config_path VOCODER_CONFIG_PATH]
#            [--encoder_path ENCODER_PATH]
#            [--encoder_config_path ENCODER_CONFIG_PATH] [--pipe_out [PIPE_OUT]]
#            [--speakers_file_path SPEAKERS_FILE_PATH]
#            [--language_ids_file_path LANGUAGE_IDS_FILE_PATH]
#            [--speaker_idx SPEAKER_IDX] [--language_idx LANGUAGE_IDX]
#            [--speaker_wav SPEAKER_WAV [SPEAKER_WAV ...]]
#            [--gst_style GST_STYLE]
#            [--capacitron_style_wav CAPACITRON_STYLE_WAV]
#            [--capacitron_style_text CAPACITRON_STYLE_TEXT]
#            [--list_speaker_idxs [LIST_SPEAKER_IDXS]]
#            [--list_language_idxs [LIST_LANGUAGE_IDXS]]
#            [--save_spectogram SAVE_SPECTOGRAM] [--reference_wav REFERENCE_WAV]
#            [--reference_speaker_idx REFERENCE_SPEAKER_IDX]
#            [--progress_bar PROGRESS_BAR] [--source_wav SOURCE_WAV]
#            [--target_wav TARGET_WAV] [--voice_dir VOICE_DIR]
# tts: error: unrecognized arguments: --action train

# %%
# Generate a speech sample using the trained model
model_path = os.path.join(output_path, 'best_model.pth')  # Adjust if different
sample_text = "Hello, this is a test sentence."

# !tts --model_path {model_path} --config_path {config_path} --out_path {samples_path} --text "{sample_text}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Generate a speech sample using the trained model
# ----> 2 model_path = os.path.join(output_path, 'best_model.pth')  # Adjust if different
#       3 sample_text = "Hello, this is a test sentence."
#       5 get_ipython().system('tts --model_path {model_path} --config_path {config_path} --out_path {samples_path} --text "{sample_text}"')
#
# NameError: name 'output_path' is not defined

# %%
# Play the generated audio directly in the notebook
from IPython.display import Audio

audio_file = os.path.join(samples_path, 'test.wav')
Audio(audio_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Play the generated audio directly in the notebook
#       2 from IPython.display import Audio
# ----> 4 audio_file = os.path.join(samples_path, 'test.wav')
#       5 Audio(audio_file)
#
# NameError: name 'samples_path' is not defined

# %%
# ============================
# 🛠️ **Setup and Installation**
# ============================

# **1. Install Coqui TTS**
# Install the Coqui TTS library using pip. This step is crucial to ensure all necessary modules are available.
# Run this cell first. If TTS is already installed, you can skip this step or reinstall to ensure it's up-to-date.

# !pip install TTS --upgrade

# **2. Verify Installation**
# Import the TTS module to confirm it's installed correctly. This should run without errors.

import TTS
print(f"Coqui TTS Version: {TTS.__version__}")

# ============================
# 📁 **Path Configuration**
# ============================

import os
from TTS.utils.config import load_config

# **3. Define Project Paths**
# Set up directories for your project, configuration, dataset, output, and samples.

project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
config_path = os.path.join(project_dir, 'config', 'custom_config.json')
dataset_path = os.path.join(project_dir, 'moz_dataset')
output_path = os.path.join(project_dir, 'output')
samples_path = os.path.join(project_dir, 'samples')

# **4. Create Output Directories**
# Ensure that the `output` and `samples` directories exist. If not, create them.

os.makedirs(output_path, exist_ok=True)
os.makedirs(samples_path, exist_ok=True)

# **5. Load Configuration**
# Load the TTS configuration from the specified JSON file. Ensure that `custom_config.json` exists in the `config` directory.

try:
    config = load_config(config_path)
    print("Configuration loaded successfully!")
except FileNotFoundError:
    print(f"Configuration file not found at: {config_path}")
except Exception as e:
    print(f"An error occurred while loading configuration: {e}")

# ============================
# 📂 **Dataset Preprocessing**
# ============================

# **6. Preprocess the Dataset**
# Preprocess the dataset using Coqui TTS's preprocessing capabilities.
# Note: The `--action preprocess` argument may vary based on the TTS version. Ensure you're using the correct command as per the installed version.

# !tts --config_path {config_path} --action preprocess

# **📌 Troubleshooting Preprocessing Errors:**
# - **Error:** `tts: error: unrecognized arguments: --action preprocess`
# - **Solution:** Ensure you're using the latest version of Coqui TTS and refer to the [Coqui TTS Documentation](https://tts.readthedocs.io/en/latest/).

# ============================
# 🎓 **Model Training**
# ============================

# **7. Train the TTS Model**
# Initiate the training process for the TTS model based on the preprocessed data and configuration.
# Similar to preprocessing, ensure the command aligns with your TTS version.

# !tts --config_path {config_path} --action train

# **📌 Troubleshooting Training Errors:**
# - **Error:** `tts: error: unrecognized arguments: --action train`
# - **Solution:** Verify the TTS version and update commands accordingly. Check the [Coqui TTS Training Guide](https://tts.readthedocs.io/en/latest/train.html).

# ============================
# 🎤 **Speech Generation**
# ============================

# **8. Generate Speech Sample**
# Use the trained model to generate speech from the provided text. Ensure that the training process has completed successfully and that `best_model.pth` exists in the `output` directory.

model_path = os.path.join(output_path, 'best_model.pth')  # Adjust if your model has a different name
sample_text = "Hello, this is a test sentence."

# **Check if the Model Exists**
if os.path.isfile(model_path):
    # !tts --model_path {model_path} --config_path {config_path} --out_path {samples_path} --text "{sample_text}"
    print(f"Speech generated and saved to {samples_path}")
else:
    print(f"Trained model not found at: {model_path}")

# **📌 Troubleshooting Generation Errors:**
# - **Error:** `NameError: name 'output_path' is not defined`
# - **Solution:** Ensure that the previous cells ran successfully without errors, especially the path configurations.

# ============================
# 🔊 **Audio Playback**
# ============================

# **9. Play the Generated Audio**
# Embed an audio player in the notebook to listen to the generated speech.

from IPython.display import Audio

audio_file = os.path.join(samples_path, 'test.wav')  # Ensure this filename matches the output from the generation step

# **Check if the Audio File Exists**
if os.path.isfile(audio_file):
    Audio(audio_file)
else:
    print(f"Audio file not found at: {audio_file}")

# %%
# ============================
# 🛠️ **Setup and Installation**
# ============================

# **1. Install Coqui TTS**
# Install the Coqui TTS library using pip. This step is crucial to ensure all necessary modules are available.
# Run this cell first. If TTS is already installed, you can skip this step or reinstall to ensure it's up-to-date.

# !pip install TTS --upgrade

# **2. Verify Installation**
# Import the TTS module to confirm it's installed correctly. This should run without errors.

import TTS
print(f"Coqui TTS Version: {TTS.__version__}")
# Out:
# Requirement already satisfied: TTS in ./tts_env1/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: cython>=0.29.30 in ./tts_env1/lib/python3.10/site-packages (from TTS) (3.0.11)
# Requirement already satisfied: scipy>=1.11.2 in ./tts_env1/lib/python3.10/site-packages (from TTS) (1.11.4)
# Requirement already satisfied: torch>=2.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (2.5.1)
# Requirement already satisfied: torchaudio in ./tts_env1/lib/python3.10/site-packages (from TTS) (2.5.1)
# Requirement already satisfied: soundfile>=0.12.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.12.1)
# Requirement already satisfied: librosa>=0.10.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.10.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (1.6.0)
# Requirement already satisfied: inflect>=5.6.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (7.4.0)
# Requirement already satisfied: tqdm>=4.64.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (4.67.1)
# Requirement already satisfied: anyascii>=0.3.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.3.2)
# Requirement already satisfied: pyyaml>=6.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (2024.10.0)
# Requirement already satisfied: aiohttp>=3.8.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (3.11.11)
# Requirement already satisfied: packaging>=23.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (24.2)
# Requirement already satisfied: flask>=2.0.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (3.1.0)
# Requirement already satisfied: pysbd>=0.3.4 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.5.7)
# Requirement already satisfied: pandas<2.0,>=1.4 in ./tts_env1/lib/python3.10/site-packages (from TTS) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (3.8.4)
# Requirement already satisfied: trainer>=0.0.32 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.0.17)
# Requirement already satisfied: jieba in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.42.1)
# Requirement already satisfied: pypinyin in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.53.0)
# Requirement already satisfied: hangul-romanize in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in ./tts_env1/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.2.3)
# Requirement already satisfied: jamo in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.4.1)
# Requirement already satisfied: nltk in ./tts_env1/lib/python3.10/site-packages (from TTS) (3.9.1)
# Requirement already satisfied: g2pkk>=0.1.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.1.2)
# Requirement already satisfied: bangla in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.0.2)
# Requirement already satisfied: bnnumerizer in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.1.7)
# Requirement already satisfied: einops>=0.6.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.8.0)
# Requirement already satisfied: transformers>=4.33.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (4.47.1)
# Requirement already satisfied: encodec>=0.1.1 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in ./tts_env1/lib/python3.10/site-packages (from TTS) (1.3.8)
# Requirement already satisfied: num2words in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.5.14)
# Requirement already satisfied: spacy>=3 in ./tts_env1/lib/python3.10/site-packages (from spacy[ja]>=3->TTS) (3.8.3)
# Requirement already satisfied: numpy==1.22.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (1.22.0)
# Requirement already satisfied: numba>=0.57.0 in ./tts_env1/lib/python3.10/site-packages (from TTS) (0.60.0)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.16.0)
# Requirement already satisfied: dateparser~=1.1.0 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (0.13.0)
# Requirement already satisfied: gruut_lang_en~=2.0.0 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in ./tts_env1/lib/python3.10/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (0.9.11)
# Requirement already satisfied: gruut_lang_es~=2.0.0 in ./tts_env1/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.1)
# Requirement already satisfied: gruut_lang_fr~=2.0.0 in ./tts_env1/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.2)
# Requirement already satisfied: gruut_lang_de~=2.0.0 in ./tts_env1/lib/python3.10/site-packages (from gruut[de,es,fr]==2.2.3->TTS) (2.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./tts_env1/lib/python3.10/site-packages (from aiohttp>=3.8.1->TTS) (1.18.3)
# Requirement already satisfied: Werkzeug>=3.1 in ./tts_env1/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in ./tts_env1/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in ./tts_env1/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in ./tts_env1/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in ./tts_env1/lib/python3.10/site-packages (from flask>=2.0.1->TTS) (1.9.0)
# Requirement already satisfied: more-itertools>=8.5.0 in ./tts_env1/lib/python3.10/site-packages (from inflect>=5.6.0->TTS) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in ./tts_env1/lib/python3.10/site-packages (from inflect>=5.6.0->TTS) (4.4.1)
# Requirement already satisfied: audioread>=2.1.9 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (0.4)
# Requirement already satisfied: msgpack>=1.0 in ./tts_env1/lib/python3.10/site-packages (from librosa>=0.10.0->TTS) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (1.4.7)
# Requirement already satisfied: pillow>=8 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./tts_env1/lib/python3.10/site-packages (from matplotlib>=3.7.0->TTS) (2.9.0.post0)
# Requirement already satisfied: docopt>=0.6.2 in ./tts_env1/lib/python3.10/site-packages (from num2words->TTS) (0.6.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./tts_env1/lib/python3.10/site-packages (from numba>=0.57.0->TTS) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in ./tts_env1/lib/python3.10/site-packages (from pandas<2.0,>=1.4->TTS) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./tts_env1/lib/python3.10/site-packages (from scikit-learn>=1.3.0->TTS) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in ./tts_env1/lib/python3.10/site-packages (from soundfile>=0.12.0->TTS) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (8.3.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (0.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (2.10.4)
# Requirement already satisfied: setuptools in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (75.6.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./tts_env1/lib/python3.10/site-packages (from spacy>=3->spacy[ja]>=3->TTS) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in ./tts_env1/lib/python3.10/site-packages (from spacy[ja]>=3->TTS) (0.6.9)
# Requirement already satisfied: sudachidict_core>=20211220 in ./tts_env1/lib/python3.10/site-packages (from spacy[ja]>=3->TTS) (20241021)
# Requirement already satisfied: filelock in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (3.16.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in ./tts_env1/lib/python3.10/site-packages (from torch>=2.1->TTS) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./tts_env1/lib/python3.10/site-packages (from sympy==1.13.1->torch>=2.1->TTS) (1.3.0)
# Requirement already satisfied: psutil in ./tts_env1/lib/python3.10/site-packages (from trainer>=0.0.32->TTS) (6.1.0)
# Requirement already satisfied: tensorboard in ./tts_env1/lib/python3.10/site-packages (from trainer>=0.0.32->TTS) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in ./tts_env1/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (0.27.0)
# Requirement already satisfied: regex!=2019.12.17 in ./tts_env1/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./tts_env1/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in ./tts_env1/lib/python3.10/site-packages (from transformers>=4.33.0->TTS) (0.4.5)
# Requirement already satisfied: pynndescent>=0.5 in ./tts_env1/lib/python3.10/site-packages (from umap-learn>=0.5.1->TTS) (0.5.13)
# Requirement already satisfied: pycparser in ./tts_env1/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.0->TTS) (2.22)
# Requirement already satisfied: tzlocal in ./tts_env1/lib/python3.10/site-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./tts_env1/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask>=2.0.1->TTS) (3.0.2)
# Requirement already satisfied: six in ./tts_env1/lib/python3.10/site-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS) (1.17.0)
# Requirement already satisfied: language-data>=1.2 in ./tts_env1/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in ./tts_env1/lib/python3.10/site-packages (from pooch>=1.0->librosa>=0.10.0->TTS) (4.3.6)
# Requirement already satisfied: annotated-types>=0.6.0 in ./tts_env1/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./tts_env1/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./tts_env1/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./tts_env1/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./tts_env1/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./tts_env1/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS) (2024.12.14)
# Requirement already satisfied: blis<1.2.0,>=1.1.0 in ./tts_env1/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy>=3->spacy[ja]>=3->TTS) (1.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./tts_env1/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy>=3->spacy[ja]>=3->TTS) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in ./tts_env1/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./tts_env1/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./tts_env1/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./tts_env1/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (7.1.0)
# Requirement already satisfied: absl-py>=0.4 in ./tts_env1/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in ./tts_env1/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in ./tts_env1/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in ./tts_env1/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (5.29.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./tts_env1/lib/python3.10/site-packages (from tensorboard->trainer>=0.0.32->TTS) (0.7.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./tts_env1/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./tts_env1/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./tts_env1/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (2.18.0)
# Requirement already satisfied: wrapt in ./tts_env1/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in ./tts_env1/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS) (0.1.2)
# Coqui TTS Version: 0.22.0

# %%
# ============================
# 📁 **Path Configuration**
# ============================

import os
from TTS.utils.config import load_config

# **3. Define Project Paths**
# Set up directories for your project, configuration, dataset, output, and samples.

project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
config_path = os.path.join(project_dir, 'config', 'custom_config.json')
dataset_path = os.path.join(project_dir, 'moz_dataset')
output_path = os.path.join(project_dir, 'output')
samples_path = os.path.join(project_dir, 'samples')

# **4. Create Output Directories**
# Ensure that the `output` and `samples` directories exist. If not, create them.

os.makedirs(output_path, exist_ok=True)
os.makedirs(samples_path, exist_ok=True)

# **5. Load Configuration**
# Load the TTS configuration from the specified JSON file. Ensure that `custom_config.json` exists in the `config` directory.

try:
    config = load_config(config_path)
    print("Configuration loaded successfully!")
except FileNotFoundError:
    print(f"Configuration file not found at: {config_path}")
except Exception as e:
    print(f"An error occurred while loading configuration: {e}")
# ============================
# 📁 **Path Configuration**
# ============================

import os
from TTS.utils.config import load_config

# **3. Define Project Paths**
# Set up directories for your project, configuration, dataset, output, and samples.

project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
config_path = os.path.join(project_dir, 'config', 'custom_config.json')
dataset_path = os.path.join(project_dir, 'moz_dataset')
output_path = os.path.join(project_dir, 'output')
samples_path = os.path.join(project_dir, 'samples')

# **4. Create Output Directories**
# Ensure that the `output` and `samples` directories exist. If not, create them.

os.makedirs(output_path, exist_ok=True)
os.makedirs(samples_path, exist_ok=True)

# **5. Load Configuration**
# Load the TTS configuration from the specified JSON file. Ensure that `custom_config.json` exists in the `config` directory.

try:
    config = load_config(config_path)
    print("Configuration loaded successfully!")
except FileNotFoundError:
    print(f"Configuration file not found at: {config_path}")
except Exception as e:
    print(f"An error occurred while loading configuration: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       1 # ============================
#       2 # 📁 **Path Configuration**
#       3 # ============================
#       5 import os
# ----> 6 from TTS.utils.config import load_config
#       8 # **3. Define Project Paths**
#       9 # Set up directories for your project, configuration, dataset, output, and samples.
#      11 project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
#
# ModuleNotFoundError: No module named 'TTS.utils.config'

# %%
# Install ipykernel if not already installed
# !pip install --upgrade ipykernel
# Out:
# Requirement already satisfied: ipykernel in ./tts_env1/lib/python3.10/site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (8.30.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (24.2)
# Requirement already satisfied: psutil in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./tts_env1/lib/python3.10/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: exceptiongroup in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack_data in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in ./tts_env1/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./tts_env1/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./tts_env1/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./tts_env1/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./tts_env1/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in ./tts_env1/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in ./tts_env1/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./tts_env1/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./tts_env1/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in ./tts_env1/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
# Register the virtual environment as a new Jupyter kernel
# !python -m ipykernel install --user --name=tts_env1 --display-name "Python (tts_env1)"
# Out:
# Installed kernelspec tts_env1 in /root/.local/share/jupyter/kernels/tts_env1

# %%
import os
from TTS.utils.config import load_config

# Define project directory
project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')

# Define paths for configuration, dataset, output, and samples
config_path = os.path.join(project_dir, 'config', 'custom_config.json')
dataset_path = os.path.join(project_dir, 'moz_dataset')
output_path = os.path.join(project_dir, 'output')
samples_path = os.path.join(project_dir, 'samples')

# Create output and samples directories if they don't exist
os.makedirs(output_path, exist_ok=True)
os.makedirs(samples_path, exist_ok=True)

# Load TTS configuration
try:
    config = load_config(config_path)
    print("Configuration loaded successfully!")
except ModuleNotFoundError as e:
    print(f"Module not found: {e}. Ensure that Coqui TTS is installed correctly in this environment.")
except FileNotFoundError:
    print(f"Configuration file not found at: {config_path}")
except Exception as e:
    print(f"An error occurred while loading configuration: {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 from TTS.utils.config import load_config
#       4 # Define project directory
#       5 project_dir = os.path.expanduser('/mnt/c/Users/Pratheek/Desktop/nlp/tts')
#
# ModuleNotFoundError: No module named 'TTS.utils.config'
